# %%
from pyrope.core import Exercise
from pyrope.nodes import Problem, Expression
from steckbriefe import Dataset, Steckbrief
from sympy import pi, latex

# %%
dataset = Dataset()

# %%
s = Steckbrief('sin(x)')
print(s.function)
s.zeros_exact
# Out:
# sin(x)
# Union(ImageSet(Lambda(_n, 2*_n*pi + pi), Integers), ImageSet(Lambda(_n, 2*_n*pi), Integers))

# %%
class DerivativeExercise(Exercise):
    def parameters(self, steckbrief=None):
        if steckbrief == None:
            steckbrief = dataset.depth(2).random_steckbrief()
        return dict(steckbrief=steckbrief, function=steckbrief.function)
    
    def problem(self, function):
        return Problem(
            """
            Calculate the derivative of
            <<function>>
            <<answer>>
            """,
            answer=Expression(symbols='x')
        )

    def the_solution(self, steckbrief):
        return steckbrief.derivative

# %%
e = DerivativeExercise()
e.run()
# Out:
# <style>
# /* css for the jupyter frontend */
#
# /* global variables */
# :root {
#     --blue: #1476fb;
#     --red: #ff0000;
#     --grey: #8b8b8b;
#     --light-grey: #efefef;
#     --black: #000000;
# }
#
# /* so that tables created by pandoc have same font size */
# .rendered_html table {
#     font-size: inherit;
# }
#
# /*  override css for MathJax_Display class */
# div.pyrope .MathJax_Display {
#     text-align: center !important;
#     display: inline-block !important;
# }
#
# /* Paragraphs should be rendered as inline elements. */
# div.pyrope p {
#     display: inline;
# }
#
# /* base css class */
# .pyrope {
#     margin-top: 3px;
#     margin-bottom: 3px;
# }
#
# table.pyrope {
#     display: inline;
#     vertical-align: middle;
# }
#
# table.pyrope * {
#     background: white;
#     text-align: left;
# }
#
# /* all children of span.pyrope are displayed as inline elements and centered vertically */
# span.pyrope * {
#     display: inline;
#     vertical-align: middle;
# }
#
# /* Labels are used to show the values of widgets. */
# label.pyrope {
#     margin-left: 3px;
#     margin-right: 3px;
# }
# label.pyrope:empty {
#     margin-left: 0px;
#     margin-right: 0px;
# }
#
# /* Styles for widget's score span. */
# span.pyrope.score, span.pyrope.solution {
#     vertical-align: middle;
#     margin-left: 3px;
#     margin-right: 3px;
#     border: 1px solid var(--grey);
#     border-radius: 3px;
#     padding: 1px 2px;
#     background-color: var(--light-grey);
# }
# span.pyrope.score:empty, span.pyrope.solution:empty {
#     margin-left: 0px;
#     margin-right: 0px;
#     border: none;
#     padding: 0px;
# }
#
# /* Styles for widget's solution span. */
# span.pyrope.solution {
#     color: var(--blue);
# }
#
# /* Separate exercises with a horizontal rule. */
# hr.pyrope {
#     border: 1px solid #cccccc;
#     border-radius: 3px;
# }
#
# /* JupyterHtmlCheckbox */
# input[type="checkbox"].pyrope {
# 	-webkit-appearance: none;
#     border: 1px solid var(--grey);
#     width: 13px;
#     height: 13px;
#     border-radius: 2px;
# }
# input[type="checkbox"].pyrope:focus {
#     outline: none;
# }
# input[type="checkbox"].pyrope:hover:enabled {
# 	box-shadow: 0px 0px 1px var(--black);
# }
# input[type="checkbox"].pyrope:checked::before {
# 	content: "";
#     display: block;
#     width: 2px;
#     height: 4px;
#     background-color: var(--black);
#     transform: translateX(2px) translateY(6px) rotate(-50deg);
# }
# input[type="checkbox"].pyrope:checked::after {
# 	content: "";
#     display: block;
#     width: 2px;
#     height: 8px;
#     background-color: var(--black);
#     transform: translateX(6px) translateY(-3px) rotate(38deg);
# }
# input[type="checkbox"].pyrope.invalid:checked::before {
# 	background-color: var(--red);
# }
# input[type="checkbox"].pyrope.invalid:checked::after {
# 	background-color: var(--red);
# }
# input[type="checkbox"].pyrope.invalid {
# 	border-color: var(--red);
# }
# input[type="checkbox"].pyrope.valid:disabled {
# 	border-color: var(--blue);
# }
# input[type="checkbox"].pyrope.valid:disabled::before {
# 	background-color: var(--blue);
# }
# input[type="checkbox"].pyrope.valid:disabled::after {
# 	background-color: var(--blue);
# }
#
# /* JupyterHtmlDropdown */
# select.pyrope {
# 	border: 1px solid var(--grey);
#     border-radius: 2px;
# }
# select.pyrope.invalid {
# 	color: var(--red);
#     border-color: var(--red);
# }
# select.pyrope.invalid option {
# 	color: black;
# }
# select.pyrope.invalid:focus {
#     outline-color: var(--red);
# }
# select.pyrope.valid:disabled {
# 	color: var(--blue);
#     border-color: var(--blue);
# }
#
# /* JupyterHtmlRadiobutton */
# input[type="radio"].pyrope {
# 	-webkit-appearance: none;
#     width: 13px;
#     height: 13px;
#     border: 1px solid var(--grey);
#     border-radius: 50%;
#     vertical-align: text-bottom;
# }
# input[type="radio"].pyrope:focus {
#     outline: none;
# }
# input[type="radio"].pyrope:hover:enabled {
# 	box-shadow: 0px 0px 1px var(--black);
# }
# input[type="radio"].pyrope:checked::before {
# 	content: "";
#     display: block;
#     position: relative;
#     width: 7px;
#     height: 7px;
#     border-radius: 50%;
#     background-color: var(--black);
#     transform: translateX(2px) translateY(2px);
# }
# input[type="radio"].pyrope.invalid {
# 	border-color: var(--red);
# }
# input[type="radio"].pyrope.invalid:checked::before {
# 	background-color: var(--red);
# }
# input[type="radio"].pyrope.valid:disabled {
# 	border-color: var(--blue);
# }
# input[type="radio"].pyrope.valid:disabled:checked::before {
# 	background-color: var(--blue);
# }
#
# /* JupyterHtmlText */
# input[type="text"].pyrope {
# 	border: 1px solid var(--grey);
#     border-radius: 2px;
#     padding: 2px;
#     vertical-align: middle;
# }
# input[type="text"].pyrope:focus {
# 	border-color: var(--black);
# 	outline-color: var(--black);
# 	outline-style: solid;
# }
# input[type="text"].pyrope.invalid {
#     border-color: var(--red);
#     color: var(--red);
# }
# input[type="text"].pyrope.invalid:focus {
#     outline-color: var(--red);
# }
# input[type="text"].pyrope.valid {
#     border-color: var(--blue);
# }
# input[type="text"].pyrope.valid:focus {
#     outline-color: var(--blue);
# }
# input[type="text"].pyrope.valid:disabled {
# 	color: var(--blue);
# }
#
# /* JupyterHtmlTextarea */
# textarea.pyrope {
# 	border: 1px solid var(--grey);
#     border-radius: 2px;
#     padding: 2px;
#     vertical-align: middle;
# }
# textarea.pyrope:focus {
# 	outline-style: solid;
#     outline-color: var(--black);
#     border-color: var(--black);
# }
# textarea.pyrope.invalid {
#     border-color: var(--red);
#     color: var(--red);
# }
# textarea.pyrope.invalid:focus {
#     outline-color: var(--red);
# }
# textarea.pyrope.valid {
#     border-color: var(--blue);
# }
# textarea.pyrope.valid:focus {
#     outline-color: var(--blue);
# }
# textarea.pyrope.valid:disabled {
# 	color: var(--blue);
# }
#
# /* JupyterHtmlSlider */
# input[type="range"].pyrope {
#     -webkit-appearance: none;
#     background-color: var(--light-grey);
#     height: 5px;
#     border-radius: 10px;
#     border: 1px solid var(--grey);
#     width: 25%;
#     vertical-align: middle;
#     display: inline;
# }
# input[type="range"].pyrope::-webkit-slider-thumb {
#     -webkit-appearance: none;
#     background: var(--black);
#     border-radius: 50%;
#     cursor: pointer;
#     height: 15px;
#     width: 15px;
# }
# input[type="range"].pyrope.invalid {
# 	border-color: var(--red);
# }
# input[type="range"].pyrope.invalid::-webkit-slider-thumb {
# 	background: var(--red);
# }
# input[type="range"].pyrope.valid:disabled {
# 	border-color: var(--blue);
# }
# input[type="range"].pyrope.valid:disabled::-webkit-slider-thumb {
# 	background: var(--blue);
# }
# input[type="range"].pyrope::-moz-range-thumb {
#     -webkit-appearance: none;
#     background: var(--black);
#     border-width: 0px;
#     border-radius: 50%;
#     cursor: pointer;
#     height: 15px;
#     width: 15px;
# }
# input[type="range"].pyrope.valid:disabled::-moz-range-thumb {
# 	background: var(--blue);
# }
# input[type="range"].pyrope.invalid::-moz-range-thumb {
# 	background: var(--red);
# }
#
#
# /*
# css code generated by Pandoc using pygments highlighting style
# https://github.com/jgm/pandoc
# */
# pre > code.sourceCode { white-space: pre; position: relative; }
# pre > code.sourceCode > span { display: inline-block; line-height: 1.25; }
# pre > code.sourceCode > span:empty { height: 1.2em; }
# .sourceCode { overflow: visible; }
# code.sourceCode > span { color: inherit; text-decoration: inherit; }
# div.sourceCode { margin: 1em 0; }
# pre.sourceCode { margin: 0; }
# @media screen {
# div.sourceCode { overflow: auto; }
# }
# @media print {
# pre > code.sourceCode { white-space: pre-wrap; }
# pre > code.sourceCode > span { text-indent: -5em; padding-left: 5em; }
# }
# pre.numberSource code
#   { counter-reset: source-line 0; }
# pre.numberSource code > span
#   { position: relative; left: -4em; counter-increment: source-line; }
# pre.numberSource code > span > a:first-child::before
#   { content: counter(source-line);
#     position: relative; left: -1em; text-align: right; vertical-align: baseline;
#     border: none; display: inline-block;
#     -webkit-touch-callout: none; -webkit-user-select: none;
#     -khtml-user-select: none; -moz-user-select: none;
#     -ms-user-select: none; user-select: none;
#     padding: 0 4px; width: 4em;
#     color: #aaaaaa;
#   }
# pre.numberSource { margin-left: 3em; border-left: 1px solid #aaaaaa;  padding-left: 4px; }
# <div class="pyrope"><p>Calculate the derivative of<br />
# $\displaystyle 8 - 4 x$<br />
# <input type="text" data-pyrope-id="id_10429f918ca84ea1afa84958a15be421" class="pyrope valid" title="" placeholder="" style="width: 20ch;" oninput="PyRope.send('id_10429f918ca84ea1afa84958a15be421', this.value)"><span data-pyrope-id="id_3fbcebd8a64d47bdb0d4c75417848166" class="pyrope solution"></span><span data-pyrope-id="id_56aacbebd7844d53921ebc4ae1f087fb" class="pyrope score"></span></p></div>
# JupyterSubmitSection(children=(HBox(children=(Button(description='Submit', style=ButtonStyle()),)), Box(layout…

# %%
class AsymptoteExercise(Exercise):
    def parameters(self, steckbrief=None):
        if steckbrief == None:
            steckbrief = dataset.asymptotes_count(1).random_steckbrief()
        return dict(steckbrief=steckbrief, function=steckbrief.function)
    
    def problem(self, function):
        return Problem(
            """
            Calculate the asymptote of
            <<function>>
            <<answer>>
            """,
            answer=Expression(symbols='x')
        )

    def the_solution(self, steckbrief):
        return steckbrief.asymptotes[0]

# %%
e = AsymptoteExercise()
e.run()
# Out:
# <style>
# /* css for the jupyter frontend */
#
# /* global variables */
# :root {
#     --blue: #1476fb;
#     --red: #ff0000;
#     --grey: #8b8b8b;
#     --light-grey: #efefef;
#     --black: #000000;
# }
#
# /* so that tables created by pandoc have same font size */
# .rendered_html table {
#     font-size: inherit;
# }
#
# /*  override css for MathJax_Display class */
# div.pyrope .MathJax_Display {
#     text-align: center !important;
#     display: inline-block !important;
# }
#
# /* Paragraphs should be rendered as inline elements. */
# div.pyrope p {
#     display: inline;
# }
#
# /* base css class */
# .pyrope {
#     margin-top: 3px;
#     margin-bottom: 3px;
# }
#
# table.pyrope {
#     display: inline;
#     vertical-align: middle;
# }
#
# table.pyrope * {
#     background: white;
#     text-align: left;
# }
#
# /* all children of span.pyrope are displayed as inline elements and centered vertically */
# span.pyrope * {
#     display: inline;
#     vertical-align: middle;
# }
#
# /* Labels are used to show the values of widgets. */
# label.pyrope {
#     margin-left: 3px;
#     margin-right: 3px;
# }
# label.pyrope:empty {
#     margin-left: 0px;
#     margin-right: 0px;
# }
#
# /* Styles for widget's score span. */
# span.pyrope.score, span.pyrope.solution {
#     vertical-align: middle;
#     margin-left: 3px;
#     margin-right: 3px;
#     border: 1px solid var(--grey);
#     border-radius: 3px;
#     padding: 1px 2px;
#     background-color: var(--light-grey);
# }
# span.pyrope.score:empty, span.pyrope.solution:empty {
#     margin-left: 0px;
#     margin-right: 0px;
#     border: none;
#     padding: 0px;
# }
#
# /* Styles for widget's solution span. */
# span.pyrope.solution {
#     color: var(--blue);
# }
#
# /* Separate exercises with a horizontal rule. */
# hr.pyrope {
#     border: 1px solid #cccccc;
#     border-radius: 3px;
# }
#
# /* JupyterHtmlCheckbox */
# input[type="checkbox"].pyrope {
# 	-webkit-appearance: none;
#     border: 1px solid var(--grey);
#     width: 13px;
#     height: 13px;
#     border-radius: 2px;
# }
# input[type="checkbox"].pyrope:focus {
#     outline: none;
# }
# input[type="checkbox"].pyrope:hover:enabled {
# 	box-shadow: 0px 0px 1px var(--black);
# }
# input[type="checkbox"].pyrope:checked::before {
# 	content: "";
#     display: block;
#     width: 2px;
#     height: 4px;
#     background-color: var(--black);
#     transform: translateX(2px) translateY(6px) rotate(-50deg);
# }
# input[type="checkbox"].pyrope:checked::after {
# 	content: "";
#     display: block;
#     width: 2px;
#     height: 8px;
#     background-color: var(--black);
#     transform: translateX(6px) translateY(-3px) rotate(38deg);
# }
# input[type="checkbox"].pyrope.invalid:checked::before {
# 	background-color: var(--red);
# }
# input[type="checkbox"].pyrope.invalid:checked::after {
# 	background-color: var(--red);
# }
# input[type="checkbox"].pyrope.invalid {
# 	border-color: var(--red);
# }
# input[type="checkbox"].pyrope.valid:disabled {
# 	border-color: var(--blue);
# }
# input[type="checkbox"].pyrope.valid:disabled::before {
# 	background-color: var(--blue);
# }
# input[type="checkbox"].pyrope.valid:disabled::after {
# 	background-color: var(--blue);
# }
#
# /* JupyterHtmlDropdown */
# select.pyrope {
# 	border: 1px solid var(--grey);
#     border-radius: 2px;
# }
# select.pyrope.invalid {
# 	color: var(--red);
#     border-color: var(--red);
# }
# select.pyrope.invalid option {
# 	color: black;
# }
# select.pyrope.invalid:focus {
#     outline-color: var(--red);
# }
# select.pyrope.valid:disabled {
# 	color: var(--blue);
#     border-color: var(--blue);
# }
#
# /* JupyterHtmlRadiobutton */
# input[type="radio"].pyrope {
# 	-webkit-appearance: none;
#     width: 13px;
#     height: 13px;
#     border: 1px solid var(--grey);
#     border-radius: 50%;
#     vertical-align: text-bottom;
# }
# input[type="radio"].pyrope:focus {
#     outline: none;
# }
# input[type="radio"].pyrope:hover:enabled {
# 	box-shadow: 0px 0px 1px var(--black);
# }
# input[type="radio"].pyrope:checked::before {
# 	content: "";
#     display: block;
#     position: relative;
#     width: 7px;
#     height: 7px;
#     border-radius: 50%;
#     background-color: var(--black);
#     transform: translateX(2px) translateY(2px);
# }
# input[type="radio"].pyrope.invalid {
# 	border-color: var(--red);
# }
# input[type="radio"].pyrope.invalid:checked::before {
# 	background-color: var(--red);
# }
# input[type="radio"].pyrope.valid:disabled {
# 	border-color: var(--blue);
# }
# input[type="radio"].pyrope.valid:disabled:checked::before {
# 	background-color: var(--blue);
# }
#
# /* JupyterHtmlText */
# input[type="text"].pyrope {
# 	border: 1px solid var(--grey);
#     border-radius: 2px;
#     padding: 2px;
#     vertical-align: middle;
# }
# input[type="text"].pyrope:focus {
# 	border-color: var(--black);
# 	outline-color: var(--black);
# 	outline-style: solid;
# }
# input[type="text"].pyrope.invalid {
#     border-color: var(--red);
#     color: var(--red);
# }
# input[type="text"].pyrope.invalid:focus {
#     outline-color: var(--red);
# }
# input[type="text"].pyrope.valid {
#     border-color: var(--blue);
# }
# input[type="text"].pyrope.valid:focus {
#     outline-color: var(--blue);
# }
# input[type="text"].pyrope.valid:disabled {
# 	color: var(--blue);
# }
#
# /* JupyterHtmlTextarea */
# textarea.pyrope {
# 	border: 1px solid var(--grey);
#     border-radius: 2px;
#     padding: 2px;
#     vertical-align: middle;
# }
# textarea.pyrope:focus {
# 	outline-style: solid;
#     outline-color: var(--black);
#     border-color: var(--black);
# }
# textarea.pyrope.invalid {
#     border-color: var(--red);
#     color: var(--red);
# }
# textarea.pyrope.invalid:focus {
#     outline-color: var(--red);
# }
# textarea.pyrope.valid {
#     border-color: var(--blue);
# }
# textarea.pyrope.valid:focus {
#     outline-color: var(--blue);
# }
# textarea.pyrope.valid:disabled {
# 	color: var(--blue);
# }
#
# /* JupyterHtmlSlider */
# input[type="range"].pyrope {
#     -webkit-appearance: none;
#     background-color: var(--light-grey);
#     height: 5px;
#     border-radius: 10px;
#     border: 1px solid var(--grey);
#     width: 25%;
#     vertical-align: middle;
#     display: inline;
# }
# input[type="range"].pyrope::-webkit-slider-thumb {
#     -webkit-appearance: none;
#     background: var(--black);
#     border-radius: 50%;
#     cursor: pointer;
#     height: 15px;
#     width: 15px;
# }
# input[type="range"].pyrope.invalid {
# 	border-color: var(--red);
# }
# input[type="range"].pyrope.invalid::-webkit-slider-thumb {
# 	background: var(--red);
# }
# input[type="range"].pyrope.valid:disabled {
# 	border-color: var(--blue);
# }
# input[type="range"].pyrope.valid:disabled::-webkit-slider-thumb {
# 	background: var(--blue);
# }
# input[type="range"].pyrope::-moz-range-thumb {
#     -webkit-appearance: none;
#     background: var(--black);
#     border-width: 0px;
#     border-radius: 50%;
#     cursor: pointer;
#     height: 15px;
#     width: 15px;
# }
# input[type="range"].pyrope.valid:disabled::-moz-range-thumb {
# 	background: var(--blue);
# }
# input[type="range"].pyrope.invalid::-moz-range-thumb {
# 	background: var(--red);
# }
#
#
# /*
# css code generated by Pandoc using pygments highlighting style
# https://github.com/jgm/pandoc
# */
# pre > code.sourceCode { white-space: pre; position: relative; }
# pre > code.sourceCode > span { display: inline-block; line-height: 1.25; }
# pre > code.sourceCode > span:empty { height: 1.2em; }
# .sourceCode { overflow: visible; }
# code.sourceCode > span { color: inherit; text-decoration: inherit; }
# div.sourceCode { margin: 1em 0; }
# pre.sourceCode { margin: 0; }
# @media screen {
# div.sourceCode { overflow: auto; }
# }
# @media print {
# pre > code.sourceCode { white-space: pre-wrap; }
# pre > code.sourceCode > span { text-indent: -5em; padding-left: 5em; }
# }
# pre.numberSource code
#   { counter-reset: source-line 0; }
# pre.numberSource code > span
#   { position: relative; left: -4em; counter-increment: source-line; }
# pre.numberSource code > span > a:first-child::before
#   { content: counter(source-line);
#     position: relative; left: -1em; text-align: right; vertical-align: baseline;
#     border: none; display: inline-block;
#     -webkit-touch-callout: none; -webkit-user-select: none;
#     -khtml-user-select: none; -moz-user-select: none;
#     -ms-user-select: none; user-select: none;
#     padding: 0 4px; width: 4em;
#     color: #aaaaaa;
#   }
# pre.numberSource { margin-left: 3em; border-left: 1px solid #aaaaaa;  padding-left: 4px; }
# <div class="pyrope"><p>Calculate the asymptote of<br />
# $\displaystyle x + e^{x} - 4$<br />
# <input type="text" data-pyrope-id="id_f26ce818a08e4b52be64989a7dd0f93e" class="pyrope valid" title="" placeholder="" style="width: 20ch;" oninput="PyRope.send('id_f26ce818a08e4b52be64989a7dd0f93e', this.value)"><span data-pyrope-id="id_07f3792467af49598768577b935c4ae5" class="pyrope solution"></span><span data-pyrope-id="id_5f3c74b228ba46c89d6b44ff181592af" class="pyrope score"></span></p></div>
# JupyterSubmitSection(children=(HBox(children=(Button(description='Submit', style=ButtonStyle()),)), Box(layout…

# %%
class IntegralExercise(Exercise):
    def parameters(self, steckbrief=None):
        if steckbrief == None:
            steckbrief = dataset.integral_rule('URule').random_steckbrief()
        return dict(steckbrief=steckbrief, function=steckbrief.function)
    
    def problem(self, function):
        return Problem(
            """
            Calculate the integral of
            <<function>>
            <<answer>>
            """,
            answer=Expression(symbols='x')
        )

    def the_solution(self, steckbrief):
        return steckbrief.integral
    
    def feedback(self, answer, steckbrief):
        if answer == steckbrief.integral:
            return 'Well done!'
        return 'Use these rules to calculate the integral: ' + ', '.join(steckbrief.integral_rules)

# %%
e = IntegralExercise()
e.run()
# Out:
# <style>
# /* css for the jupyter frontend */
#
# /* global variables */
# :root {
#     --blue: #1476fb;
#     --red: #ff0000;
#     --grey: #8b8b8b;
#     --light-grey: #efefef;
#     --black: #000000;
# }
#
# /* so that tables created by pandoc have same font size */
# .rendered_html table {
#     font-size: inherit;
# }
#
# /*  override css for MathJax_Display class */
# div.pyrope .MathJax_Display {
#     text-align: center !important;
#     display: inline-block !important;
# }
#
# /* Paragraphs should be rendered as inline elements. */
# div.pyrope p {
#     display: inline;
# }
#
# /* base css class */
# .pyrope {
#     margin-top: 3px;
#     margin-bottom: 3px;
# }
#
# table.pyrope {
#     display: inline;
#     vertical-align: middle;
# }
#
# table.pyrope * {
#     background: white;
#     text-align: left;
# }
#
# /* all children of span.pyrope are displayed as inline elements and centered vertically */
# span.pyrope * {
#     display: inline;
#     vertical-align: middle;
# }
#
# /* Labels are used to show the values of widgets. */
# label.pyrope {
#     margin-left: 3px;
#     margin-right: 3px;
# }
# label.pyrope:empty {
#     margin-left: 0px;
#     margin-right: 0px;
# }
#
# /* Styles for widget's score span. */
# span.pyrope.score, span.pyrope.solution {
#     vertical-align: middle;
#     margin-left: 3px;
#     margin-right: 3px;
#     border: 1px solid var(--grey);
#     border-radius: 3px;
#     padding: 1px 2px;
#     background-color: var(--light-grey);
# }
# span.pyrope.score:empty, span.pyrope.solution:empty {
#     margin-left: 0px;
#     margin-right: 0px;
#     border: none;
#     padding: 0px;
# }
#
# /* Styles for widget's solution span. */
# span.pyrope.solution {
#     color: var(--blue);
# }
#
# /* Separate exercises with a horizontal rule. */
# hr.pyrope {
#     border: 1px solid #cccccc;
#     border-radius: 3px;
# }
#
# /* JupyterHtmlCheckbox */
# input[type="checkbox"].pyrope {
# 	-webkit-appearance: none;
#     border: 1px solid var(--grey);
#     width: 13px;
#     height: 13px;
#     border-radius: 2px;
# }
# input[type="checkbox"].pyrope:focus {
#     outline: none;
# }
# input[type="checkbox"].pyrope:hover:enabled {
# 	box-shadow: 0px 0px 1px var(--black);
# }
# input[type="checkbox"].pyrope:checked::before {
# 	content: "";
#     display: block;
#     width: 2px;
#     height: 4px;
#     background-color: var(--black);
#     transform: translateX(2px) translateY(6px) rotate(-50deg);
# }
# input[type="checkbox"].pyrope:checked::after {
# 	content: "";
#     display: block;
#     width: 2px;
#     height: 8px;
#     background-color: var(--black);
#     transform: translateX(6px) translateY(-3px) rotate(38deg);
# }
# input[type="checkbox"].pyrope.invalid:checked::before {
# 	background-color: var(--red);
# }
# input[type="checkbox"].pyrope.invalid:checked::after {
# 	background-color: var(--red);
# }
# input[type="checkbox"].pyrope.invalid {
# 	border-color: var(--red);
# }
# input[type="checkbox"].pyrope.valid:disabled {
# 	border-color: var(--blue);
# }
# input[type="checkbox"].pyrope.valid:disabled::before {
# 	background-color: var(--blue);
# }
# input[type="checkbox"].pyrope.valid:disabled::after {
# 	background-color: var(--blue);
# }
#
# /* JupyterHtmlDropdown */
# select.pyrope {
# 	border: 1px solid var(--grey);
#     border-radius: 2px;
# }
# select.pyrope.invalid {
# 	color: var(--red);
#     border-color: var(--red);
# }
# select.pyrope.invalid option {
# 	color: black;
# }
# select.pyrope.invalid:focus {
#     outline-color: var(--red);
# }
# select.pyrope.valid:disabled {
# 	color: var(--blue);
#     border-color: var(--blue);
# }
#
# /* JupyterHtmlRadiobutton */
# input[type="radio"].pyrope {
# 	-webkit-appearance: none;
#     width: 13px;
#     height: 13px;
#     border: 1px solid var(--grey);
#     border-radius: 50%;
#     vertical-align: text-bottom;
# }
# input[type="radio"].pyrope:focus {
#     outline: none;
# }
# input[type="radio"].pyrope:hover:enabled {
# 	box-shadow: 0px 0px 1px var(--black);
# }
# input[type="radio"].pyrope:checked::before {
# 	content: "";
#     display: block;
#     position: relative;
#     width: 7px;
#     height: 7px;
#     border-radius: 50%;
#     background-color: var(--black);
#     transform: translateX(2px) translateY(2px);
# }
# input[type="radio"].pyrope.invalid {
# 	border-color: var(--red);
# }
# input[type="radio"].pyrope.invalid:checked::before {
# 	background-color: var(--red);
# }
# input[type="radio"].pyrope.valid:disabled {
# 	border-color: var(--blue);
# }
# input[type="radio"].pyrope.valid:disabled:checked::before {
# 	background-color: var(--blue);
# }
#
# /* JupyterHtmlText */
# input[type="text"].pyrope {
# 	border: 1px solid var(--grey);
#     border-radius: 2px;
#     padding: 2px;
#     vertical-align: middle;
# }
# input[type="text"].pyrope:focus {
# 	border-color: var(--black);
# 	outline-color: var(--black);
# 	outline-style: solid;
# }
# input[type="text"].pyrope.invalid {
#     border-color: var(--red);
#     color: var(--red);
# }
# input[type="text"].pyrope.invalid:focus {
#     outline-color: var(--red);
# }
# input[type="text"].pyrope.valid {
#     border-color: var(--blue);
# }
# input[type="text"].pyrope.valid:focus {
#     outline-color: var(--blue);
# }
# input[type="text"].pyrope.valid:disabled {
# 	color: var(--blue);
# }
#
# /* JupyterHtmlTextarea */
# textarea.pyrope {
# 	border: 1px solid var(--grey);
#     border-radius: 2px;
#     padding: 2px;
#     vertical-align: middle;
# }
# textarea.pyrope:focus {
# 	outline-style: solid;
#     outline-color: var(--black);
#     border-color: var(--black);
# }
# textarea.pyrope.invalid {
#     border-color: var(--red);
#     color: var(--red);
# }
# textarea.pyrope.invalid:focus {
#     outline-color: var(--red);
# }
# textarea.pyrope.valid {
#     border-color: var(--blue);
# }
# textarea.pyrope.valid:focus {
#     outline-color: var(--blue);
# }
# textarea.pyrope.valid:disabled {
# 	color: var(--blue);
# }
#
# /* JupyterHtmlSlider */
# input[type="range"].pyrope {
#     -webkit-appearance: none;
#     background-color: var(--light-grey);
#     height: 5px;
#     border-radius: 10px;
#     border: 1px solid var(--grey);
#     width: 25%;
#     vertical-align: middle;
#     display: inline;
# }
# input[type="range"].pyrope::-webkit-slider-thumb {
#     -webkit-appearance: none;
#     background: var(--black);
#     border-radius: 50%;
#     cursor: pointer;
#     height: 15px;
#     width: 15px;
# }
# input[type="range"].pyrope.invalid {
# 	border-color: var(--red);
# }
# input[type="range"].pyrope.invalid::-webkit-slider-thumb {
# 	background: var(--red);
# }
# input[type="range"].pyrope.valid:disabled {
# 	border-color: var(--blue);
# }
# input[type="range"].pyrope.valid:disabled::-webkit-slider-thumb {
# 	background: var(--blue);
# }
# input[type="range"].pyrope::-moz-range-thumb {
#     -webkit-appearance: none;
#     background: var(--black);
#     border-width: 0px;
#     border-radius: 50%;
#     cursor: pointer;
#     height: 15px;
#     width: 15px;
# }
# input[type="range"].pyrope.valid:disabled::-moz-range-thumb {
# 	background: var(--blue);
# }
# input[type="range"].pyrope.invalid::-moz-range-thumb {
# 	background: var(--red);
# }
#
#
# /*
# css code generated by Pandoc using pygments highlighting style
# https://github.com/jgm/pandoc
# */
# pre > code.sourceCode { white-space: pre; position: relative; }
# pre > code.sourceCode > span { display: inline-block; line-height: 1.25; }
# pre > code.sourceCode > span:empty { height: 1.2em; }
# .sourceCode { overflow: visible; }
# code.sourceCode > span { color: inherit; text-decoration: inherit; }
# div.sourceCode { margin: 1em 0; }
# pre.sourceCode { margin: 0; }
# @media screen {
# div.sourceCode { overflow: auto; }
# }
# @media print {
# pre > code.sourceCode { white-space: pre-wrap; }
# pre > code.sourceCode > span { text-indent: -5em; padding-left: 5em; }
# }
# pre.numberSource code
#   { counter-reset: source-line 0; }
# pre.numberSource code > span
#   { position: relative; left: -4em; counter-increment: source-line; }
# pre.numberSource code > span > a:first-child::before
#   { content: counter(source-line);
#     position: relative; left: -1em; text-align: right; vertical-align: baseline;
#     border: none; display: inline-block;
#     -webkit-touch-callout: none; -webkit-user-select: none;
#     -khtml-user-select: none; -moz-user-select: none;
#     -ms-user-select: none; user-select: none;
#     padding: 0 4px; width: 4em;
#     color: #aaaaaa;
#   }
# pre.numberSource { margin-left: 3em; border-left: 1px solid #aaaaaa;  padding-left: 4px; }
# <div class="pyrope"><p>Calculate the integral of<br />
# $\displaystyle \left(2 - x\right) \log{\left(x \right)}$<br />
# <input type="text" data-pyrope-id="id_b20fe6dd7090428c845273217fd3643e" class="pyrope valid" title="" placeholder="" style="width: 20ch;" oninput="PyRope.send('id_b20fe6dd7090428c845273217fd3643e', this.value)"><span data-pyrope-id="id_20af5d736056400dbdbfd256d582ac14" class="pyrope solution"></span><span data-pyrope-id="id_29f3672b058e4442bb6dac226796f594" class="pyrope score"></span></p></div>
# JupyterSubmitSection(children=(HBox(children=(Button(description='Submit', style=ButtonStyle()),)), Box(layout…

# %%
dataset.zeros_count(lambda x: x > 0).apply('zeros', lambda zeros: all([z % 1 == 0 for z in zeros])).df
# Out:
#          function function_example  depth  leaves  nodes  polynomial  \
# 0         k*(m+x)         4*x + 16      2       3      5        True
# 7    sin(x)/(k-x)   sin(x)/(4 - x)      2       3      6       False
# 9     (k+x)/(m+x)  (x + 4)/(x + 3)      2       4      7       False
# 13       log(m/x)         log(4/x)      2       2      4       False
# 17   log(x)/(k-x)   log(x)/(2 - x)      2       3      6       False
# ..            ...              ...    ...     ...    ...         ...
# 635     x*(k+x)/m      x*(x + 3)/3      2       4      7        True
# 636      -k-x+x/m         -x/2 - 2      2       3      5        True
# 640    m*log(x)/x       2*log(x)/x      2       3      6       False
# 642         k-x/m          4 - x/2      2       3      5        True
# 644       x/(m-x)        x/(4 - x)      2       3      5       False
#
#      rational                                             domain  \
# 0        True                                              Reals
# 7       False  Union(Interval.open(-oo, 4), Interval.open(4, ...
# 9        True  Union(Interval.open(-oo, -3), Interval.open(-3...
# 13      False                               Interval.open(0, oo)
# 17      False   Union(Interval.open(0, 2), Interval.open(2, oo))
# ..        ...                                                ...
# 635      True                                              Reals
# 636      True                                              Reals
# 640     False                               Interval.open(0, oo)
# 642      True                                              Reals
# 644      True  Union(Interval.open(-oo, 4), Interval.open(4, ...
#
#                                                  range  \
# 0                                    Interval(-oo, oo)
# 7                                                  NaN
# 9    Union(Interval.open(-oo, 1), Interval.open(1, ...
# 13                                   Interval(-oo, oo)
# 17                                                 NaN
# ..                                                 ...
# 635                                 Interval(-3/4, oo)
# 636                                  Interval(-oo, oo)
# 640                           Interval(-oo, 2*exp(-1))
# 642                                  Interval(-oo, oo)
# 644  Union(Interval.open(-oo, -1), Interval.open(-1...
#
#                                          singularities  ...  periodicity  \
# 0                                                  NaN  ...          NaN
# 7                          (4, 'Polstelle', (-oo, oo))  ...          NaN
# 9                         (-3, 'Polstelle', (-oo, oo))  ...          NaN
# 13                          (0, 'Polstelle', (oo, oo))  ...          NaN
# 17   (0, 'Polstelle', (-oo, -oo)),(2, 'Polstelle', ...  ...          NaN
# ..                                                 ...  ...          ...
# 635                                                NaN  ...          NaN
# 636                                                NaN  ...          NaN
# 640                        (0, 'Polstelle', (oo, -oo))  ...          NaN
# 642                                                NaN  ...          NaN
# 644                        (4, 'Polstelle', (oo, -oo))  ...          NaN
#
#      y_intercept        zeros zeros_count  zeros_exact  \
# 0           16.0       [-4.0]         1.0         {-4}
# 7            0.0        [0.0]         1.0          {0}
# 9            4/3       [-4.0]         1.0         {-4}
# 13           NaN        [4.0]         1.0          {4}
# 17           NaN        [1.0]         1.0          {1}
# ..           ...          ...         ...          ...
# 635          0.0  [-3.0, 0.0]         2.0      {-3, 0}
# 636         -2.0       [-4.0]         1.0         {-4}
# 640          NaN        [1.0]         1.0          {1}
# 642          4.0        [8.0]         1.0          {8}
# 644          0.0        [0.0]         1.0          {0}
#
#                              derivative           integral  \
# 0                                     4      2*x**2 + 16*x
# 7    cos(x)/(4 - x) + sin(x)/(4 - x)**2                NaN
# 9        1/(x + 3) - (x + 4)/(x + 3)**2     x + log(x + 3)
# 13                                 -1/x     x*log(4/x) + x
# 17    log(x)/(2 - x)**2 + 1/(x*(2 - x))                NaN
# ..                                  ...                ...
# 635                           2*x/3 + 1    x**3/9 + x**2/2
# 636                                -1/2      -x**2/4 - 2*x
# 640             -2*log(x)/x**2 + 2/x**2          log(x)**2
# 642                                -1/2      -x**2/4 + 4*x
# 644            x/(4 - x)**2 + 1/(4 - x)  -x - 4*log(x - 4)
#
#     integral_elementary                                     integral_rules  \
# 0                  True  [AddRule, ConstantTimesRule, PowerRule, Consta...
# 7                  True                                                 []
# 9                  True  [URule, RewriteRule, AddRule, ConstantRule, Re...
# 13                 True                          [PartsRule, ConstantRule]
# 17                False                                                 []
# ..                  ...                                                ...
# 635                True  [ConstantTimesRule, RewriteRule, AddRule, Powe...
# 636                True  [AddRule, ConstantTimesRule, PowerRule, Consta...
# 640                True              [ConstantTimesRule, URule, PowerRule]
# 642                True  [AddRule, ConstantRule, ConstantTimesRule, Pow...
# 644                True  [RewriteRule, AddRule, ConstantRule, ConstantT...
#
#     computation_seconds
# 0                  0.31
# 7                  0.64
# 9                  0.67
# 13                 0.60
# 17                 1.02
# ..                  ...
# 635                0.17
# 636                0.04
# 640                0.86
# 642                0.05
# 644                0.53
#
# [250 rows x 25 columns]

# %%
s = dataset.is_polynomial().zeros_count(0).random_steckbrief()
s.function
# Out:
# x**2 + x + 3

# %%
s.derivative
# Out:
# 2*x + 1

# %%
s = Steckbrief('sin(x)')
s.function
# Out:
# sin(x)

# %%
s.zeros_exact
# Out:
# Union(ImageSet(Lambda(_n, 2*_n*pi + pi), Integers), ImageSet(Lambda(_n, 2*_n*pi), Integers))

# %%
dataset.has_zero(pi).random_steckbrief().function
# Out:
# (x + 2)*sin(x)
